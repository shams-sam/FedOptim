# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
import seaborn as sns
import torch
from tqdm.notebook import tqdm

# %%
import sys
sys.path.append('../src')

# %%
hist_files = [
    '../ckpts/mnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0.pkl',
#     '../ckpts/mnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0_lbgm_0.2.pkl', 
#     '../ckpts/mnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0_lbgm_0.4.pkl', 
#     '../ckpts/mnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0_lbgm_0.6.pkl', 
    '../ckpts/mnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0_lbgm_0.8.pkl', 
#     '../ckpts/mnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0_lbgm_1.0.pkl', 
]

# %%
    def get_milestone_epoch(accs, milestone=0.q0):

# %%
fig = plt.figure(figsize=(4, 8))
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

for h in hist_files:
    epoch, acc, _, _, loss, _, _, uplink, _ = pkl.load(open(h, 'rb')) 
    ax1.plot(epoch, acc)
    ax2.plot(epoch, np.cumsum(uplink))
ax2.set_xlabel(epoch)
ax1.set_ylabel('accuracy')
ax2.set_ylabel('aggregate num. of parameters')
ax1.set_xlim(0, 50)
ax2.set_xlim(0, 50)
plt.legend(['FL', 'LBGM w/ threshold=0.8'])
plt.show()

# %%
hist_files = [
    '../ckpts/fmnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0.pkl',
    '../ckpts/fmnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0_lbgm_0.2.pkl', 
    '../ckpts/fmnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0_lbgm_0.4.pkl', 
    '../ckpts/fmnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0_lbgm_0.6.pkl', 
    '../ckpts/fmnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0_lbgm_0.8.pkl', 
    '../ckpts/fmnist_100/history/clf_fcn_optim_sgd_uniform_True_non_iid_10_num_workers_100_lr_0.01_decay_1e-05_batch_0_lbgm_1.0.pkl', 
]

# %%
fig = plt.figure(figsize=(4, 8))
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)
for h in hist_files:
    epoch, acc, _, _, loss, _, _, uplink, _ = pkl.load(open(h, 'rb')) 
    ax1.plot(epoch, acc)
    ax2.plot(epoch, np.cumsum(uplink))
plt.show()
